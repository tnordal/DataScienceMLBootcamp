# %% [markdown]
# # Class 04 of 10

# %% [markdown]
# ## EDA-pandas & interactive plotting plotly

# %% [markdown]
# ### Pandas Built-in Data Visualization

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
dates = pd.date_range('1/1/2000', periods=500)

# %%
col_d = np.random.rand(500)

# %%
data1 = np.random.randn(500, 3)

# %%
df1 = pd.DataFrame(data=data1, index=dates, columns=['A', 'B', 'C'])

# %%
df1.head()
# Out:
#                    A         B         C
# 2000-01-01 -0.458263 -0.223218  0.055697
# 2000-01-02  1.428780 -0.303110  0.425893
# 2000-01-03  0.711004  1.179901  0.956863
# 2000-01-04  0.326446 -2.059444  0.912346
# 2000-01-05  0.149839 -0.779783 -0.698642

# %%
df1['D'] = col_d

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01 -0.458263 -0.223218  0.055697  0.137107
# 2000-01-02  1.428780 -0.303110  0.425893  0.055178
# 2000-01-03  0.711004  1.179901  0.956863  0.699634
# 2000-01-04  0.326446 -2.059444  0.912346  0.256537
# 2000-01-05  0.149839 -0.779783 -0.698642  0.462019

# %%
data2 = np.random.rand(20, 3)
col = ['X', 'Z', 'Y']
df2 = pd.DataFrame(data=data2, columns=col)
df2.head()
# Out:
#           X         Z         Y
# 0  0.994042  0.730660  0.910226
# 1  0.975285  0.775557  0.770969
# 2  0.332107  0.665409  0.457950
# 3  0.678983  0.252402  0.027693
# 4  0.211420  0.666492  0.971758

# %%
df1['A'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot(kind='hist', bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
df1['A'].plot(kind='hist', bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.style.use('bmh')
df1['A'].plot(kind='hist', bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.style.use('dark_background')
df1['A'].plot(kind='hist', bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.style.use('fivethirtyeight')
df1['A'].plot(kind='hist', bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.style.use('ggplot')

# %%
df2.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
df2.plot.area(alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot.hist(bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.hist(bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.hist(bins=30, stacked=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.hist(orientation='horizontal', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df1.plot.line(y='B', lw=1, figsize=(12, 3))
# Out:
# <AxesSubplot:>

# %%
df1.plot.scatter(x='A', y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
ax = df1.plot.scatter(x='A', y='B', color='DarkBlue', label='Group1')
df1.plot.scatter(x='C', y='D', color='DarkGreen', label='Group2', ax=ax)
# Out:
# <AxesSubplot:xlabel='C', ylabel='D'>

# %%
df1.plot.scatter(x='A', y='B', c='C', cmap='coolwarm', s=50)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']*20)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df2.plot.box(vert=False)
# Out:
# <AxesSubplot:>

# %%
color = dict(
    boxes='DarkGreen',
    whiskers='DarkOrange',
    medians='DarkBlue',
    caps='Grey'
)

# %%
df2.plot.box(color=color)
# Out:
# <AxesSubplot:>

# %%
df2['group'] = np.random.choice(['A', 'B'], size=20)

# %%
df2.boxplot(column=['X', 'Y'], by='group')
# Out:
# array([<AxesSubplot:title={'center':'X'}, xlabel='group'>,
#        <AxesSubplot:title={'center':'Y'}, xlabel='group'>], dtype=object)

# %%
df2.drop('group', axis=1, inplace=True)

# %%
df1.plot.hexbin(x='A', y='B', gridsize=25, cmap='Oranges')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2['X'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.pie(y='X', figsize=(6, 6), legend=False)
# Out:
# <AxesSubplot:ylabel='X'>

# %%
df2.plot.pie(subplots=True, figsize=(16, 6), legend=False)
# Out:
# array([<AxesSubplot:ylabel='X'>, <AxesSubplot:ylabel='Z'>,
#        <AxesSubplot:ylabel='Y'>], dtype=object)

# %% [markdown]
# ## Plotly & Cufflinks

# %% [markdown]
# ## Part 1

# %%
from plotly import __version__
print(__version__)
# Out:
# 5.3.1

# %%
from plotly.offline import  download_plotlyjs

# %%
from plotly.offline import init_notebook_mode

# %%
from plotly.offline import plot, iplot

# %%
import cufflinks as cf

# %%
# To use plotly in notebook offline
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# For using pandas with plotly offline
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df1 = pd.DataFrame(np.random.randn(100, 4), columns=['A', 'B', 'C', 'D'])

# %%
df1.head()
# Out:
#           A         B         C         D
# 0 -1.828192 -1.400892 -0.090051  1.985624
# 1 -0.478008  0.869183 -0.168129 -0.504062
# 2 -1.141663 -0.138729  1.063734  0.326032
# 3  0.292099 -0.504059  1.490570  1.319845
# 4 -0.434042 -0.297685  0.608425 -0.724411

# %%
dic = {'fruit': ['apple', 'banana', 'pear', 'mango'],
      'count': [32, 43, 50, 32]}

# %%
df2 = pd.DataFrame(dic)
df2.head()
# Out:
#     fruit  count
# 0   apple     32
# 1  banana     43
# 2    pear     50
# 3   mango     32

# %%
df1.iplot()
# Out:
# <div>                            <div id="7e80603b-ed60-4e37-a23f-3a16ac7fe3b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.iplot(kind='scatter', x='A', y='B', mode='markers', size=20)
# Out:
# <div>                            <div id="bb801526-66e1-4bda-a0e5-94e7adb025bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.iplot(kind='bar', x='fruit', y='count')
# Out:
# <div>                            <div id="9cb85a24-914f-4706-a2e6-7cd6433cf42e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.iplot(kind='box')
# Out:
# <div>                            <div id="a25606b2-b5d8-4ff6-8e9f-310cdb62bb07" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3 = pd.DataFrame({'x': [1, 2, 3, 4, 5], 'y': [10, 20, 30, 20, 10], 'z': [5, 4, 3, 2, 1]})

# %%
df3
# Out:
#    x   y  z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  20  2
# 4  5  10  1

# %%
df3.iplot(kind='surface')
# Out:
# <div>                            <div id="713d8aff-4964-4d70-ac30-67c1ceeac09b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1['A'].iplot(kind='hist', bins=50)
# Out:
# <div>                            <div id="d0f2f0e2-115f-4263-8008-0e281a0e0c69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1[['A', 'B']].iplot(kind='spread')
# Out:
# /home/tn/pyvenv/DataScienceMLBootcamp/lib/python3.8/site-packages/cufflinks/plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# /home/tn/pyvenv/DataScienceMLBootcamp/lib/python3.8/site-packages/cufflinks/plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>                            <div id="ea81884a-9d50-4eb6-a191-2f2d0312c50c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.iplot(kind='bubble', x='A', y='B', size='C')
# Out:
# <div>                            <div id="51d61529-a55f-4fd6-8429-217978546ae5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.scatter_matrix()
# Out:
# <div>                            <div id="07b7eed5-d6d1-471d-bd55-58394c97f7f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
